# %%
from astroquery.mast import Observations
import numpy as np

import pandas as pd
from astropy.table import Table, vstack, hstack

import shapely


from datetime import datetime as dt
from bokeh.io import output_notebook, show, vplot
from bokeh.plotting import figure
from bokeh.layouts import column

# %% [markdown]
# # First, get the grism data and it's products for Prop 13871:

# %%
obsTable = Observations.query_criteria(filters=["G141", "G102"],dataRights=['PUBLIC'], proposal_id=['13871'] )
obsTableProducts = Observations.get_product_list(obsTable)

print obsTable
#obsTable_pandas = obsTable.to_pandas()
#print obsTable_pandas['filters'], obsTable_pandas['obsid']
print obsTableProducts
# Out:
# dataproduct_type calib_level obs_collection ...   obsid      objID
# ---------------- ----------- -------------- ... ---------- ----------
#         spectrum           3            HST ... 2003858743 2012924107
#         spectrum           3            HST ... 2003858745 2012924109
#         spectrum           3            HST ... 2003858747 2012924111
#         spectrum           3            HST ... 2004305738 2014141761
#         spectrum           3            HST ... 2004305740 2014141763
#         spectrum           3            HST ... 2004305742 2014141765
#   obsID    obs_collection dataproduct_type ...     productFilename        size
# ---------- -------------- ---------------- ... ----------------------- ---------
# 2002998239            HST         spectrum ... icka04pcq_flt_hlet.fits      8640
# 2002998239            HST         spectrum ...      icka04pcq_ima.fits 157743360
# 2002998239            HST         spectrum ...      icka04pcq_spt.fits   1152000
# 2002998239            HST         spectrum ...      icka04pcq_trl.fits     34560
# 2002998239            HST         spectrum ...      icka04pcq_raw.fits  31898880
# 2002998239            HST         spectrum ...      icka04pcq_flt.fits  16531200
# 2002998240            HST         spectrum ... icka04pdq_flt_hlet.fits      8640
# 2002998240            HST         spectrum ...      icka04pdq_ima.fits 157743360
# 2002998240            HST         spectrum ...      icka04pdq_spt.fits   1152000
# 2002998240            HST         spectrum ...      icka04pdq_trl.fits     34560
#        ...            ...              ... ...                     ...       ...
# 2004305740            HST         spectrum ...      icka02030_jit.fits    247680
# 2004305740            HST         spectrum ...      icka02030_spt.fits   4596480
# 2004305740            HST         spectrum ...      icka02030_trl.fits    152640
# 2004305740            HST         spectrum ...      icka02030_asn.fits     11520
# 2004305740            HST         spectrum ...      icka02030_drz.fits  12908160
# 2004305742            HST         spectrum ...      icka03030_jif.fits    112320
# 2004305742            HST         spectrum ...      icka03030_jit.fits    247680
# 2004305742            HST         spectrum ...      icka03030_spt.fits   4596480
# 2004305742            HST         spectrum ...      icka03030_trl.fits    152640
# 2004305742            HST         spectrum ...      icka03030_asn.fits     11520
# 2004305742            HST         spectrum ...      icka03030_drz.fits  12908160
# Length = 180 rows

# %% [markdown]
# # Filter out the FLT files:

# %%
flt_filter = Observations.filter_products(obsTableProducts,mrp_only=False,productSubGroupDescription=["FLT"])
print flt_filter.to_pandas()
# Out:
#          obsID obs_collection dataproduct_type     obs_id  \
# 0   2002998239            HST         spectrum  ICKA04PCQ
# 1   2002998240            HST         spectrum  ICKA04PDQ
# 2   2002998243            HST         spectrum  ICKA04PLQ
# 3   2002998244            HST         spectrum  ICKA04PNQ
# 4   2002998247            HST         spectrum  ICKA05PJQ
# 5   2002998248            HST         spectrum  ICKA05PKQ
# 6   2002998251            HST         spectrum  ICKA05PSQ
# 7   2002998252            HST         spectrum  ICKA05PUQ
# 8   2002998255            HST         spectrum  ICKA06G7Q
# 9   2002998256            HST         spectrum  ICKA06G8Q
# 10  2002998259            HST         spectrum  ICKA06GGQ
# 11  2002998260            HST         spectrum  ICKA06GIQ
# 12  2004300702            HST         spectrum  ICKA01T7Q
# 13  2004300703            HST         spectrum  ICKA01T8Q
# 14  2004300706            HST         spectrum  ICKA01TGQ
# 15  2004300707            HST         spectrum  ICKA01TIQ
# 16  2004300710            HST         spectrum  ICKA02UOQ
# 17  2004300711            HST         spectrum  ICKA02UPQ
# 18  2004300714            HST         spectrum  ICKA02UXQ
# 19  2004300715            HST         spectrum  ICKA02UZQ
# 20  2004300718            HST         spectrum  ICKA03D4Q
# 21  2004300719            HST         spectrum  ICKA03D5Q
# 22  2004300722            HST         spectrum  ICKA03DDQ
# 23  2004300723            HST         spectrum  ICKA03DFQ
#
#                                           description type  \
# 0   DADS FLT file - Calibrated exposure ACS/WFC3/S...    S
# 1   DADS FLT file - Calibrated exposure ACS/WFC3/S...    S
# 2   DADS FLT file - Calibrated exposure ACS/WFC3/S...    S
# 3   DADS FLT file - Calibrated exposure ACS/WFC3/S...    S
# 4   DADS FLT file - Calibrated exposure ACS/WFC3/S...    S
# 5   DADS FLT file - Calibrated exposure ACS/WFC3/S...    S
# 6   DADS FLT file - Calibrated exposure ACS/WFC3/S...    S
# 7   DADS FLT file - Calibrated exposure ACS/WFC3/S...    S
# 8   DADS FLT file - Calibrated exposure ACS/WFC3/S...    S
# 9   DADS FLT file - Calibrated exposure ACS/WFC3/S...    S
# 10  DADS FLT file - Calibrated exposure ACS/WFC3/S...    S
# 11  DADS FLT file - Calibrated exposure ACS/WFC3/S...    S
# 12  DADS FLT file - Calibrated exposure ACS/WFC3/S...    S
# 13  DADS FLT file - Calibrated exposure ACS/WFC3/S...    S
# 14  DADS FLT file - Calibrated exposure ACS/WFC3/S...    S
# 15  DADS FLT file - Calibrated exposure ACS/WFC3/S...    S
# 16  DADS FLT file - Calibrated exposure ACS/WFC3/S...    S
# 17  DADS FLT file - Calibrated exposure ACS/WFC3/S...    S
# 18  DADS FLT file - Calibrated exposure ACS/WFC3/S...    S
# 19  DADS FLT file - Calibrated exposure ACS/WFC3/S...    S
# 20  DADS FLT file - Calibrated exposure ACS/WFC3/S...    S
# 21  DADS FLT file - Calibrated exposure ACS/WFC3/S...    S
# 22  DADS FLT file - Calibrated exposure ACS/WFC3/S...    S
# 23  DADS FLT file - Calibrated exposure ACS/WFC3/S...    S
#
#                                           dataURI productType  \
# 0   mast:HST/product/icka04pcq/icka04pcq_flt.fits     SCIENCE
# 1   mast:HST/product/icka04pdq/icka04pdq_flt.fits     SCIENCE
# 2   mast:HST/product/icka04plq/icka04plq_flt.fits     SCIENCE
# 3   mast:HST/product/icka04pnq/icka04pnq_flt.fits     SCIENCE
# 4   mast:HST/product/icka05pjq/icka05pjq_flt.fits     SCIENCE
# 5   mast:HST/product/icka05pkq/icka05pkq_flt.fits     SCIENCE
# 6   mast:HST/product/icka05psq/icka05psq_flt.fits     SCIENCE
# 7   mast:HST/product/icka05puq/icka05puq_flt.fits     SCIENCE
# 8   mast:HST/product/icka06g7q/icka06g7q_flt.fits     SCIENCE
# 9   mast:HST/product/icka06g8q/icka06g8q_flt.fits     SCIENCE
# 10  mast:HST/product/icka06ggq/icka06ggq_flt.fits     SCIENCE
# 11  mast:HST/product/icka06giq/icka06giq_flt.fits     SCIENCE
# 12  mast:HST/product/icka01t7q/icka01t7q_flt.fits     SCIENCE
# 13  mast:HST/product/icka01t8q/icka01t8q_flt.fits     SCIENCE
# 14  mast:HST/product/icka01tgq/icka01tgq_flt.fits     SCIENCE
# 15  mast:HST/product/icka01tiq/icka01tiq_flt.fits     SCIENCE
# 16  mast:HST/product/icka02uoq/icka02uoq_flt.fits     SCIENCE
# 17  mast:HST/product/icka02upq/icka02upq_flt.fits     SCIENCE
# 18  mast:HST/product/icka02uxq/icka02uxq_flt.fits     SCIENCE
# 19  mast:HST/product/icka02uzq/icka02uzq_flt.fits     SCIENCE
# 20  mast:HST/product/icka03d4q/icka03d4q_flt.fits     SCIENCE
# 21  mast:HST/product/icka03d5q/icka03d5q_flt.fits     SCIENCE
# 22  mast:HST/product/icka03ddq/icka03ddq_flt.fits     SCIENCE
# 23  mast:HST/product/icka03dfq/icka03dfq_flt.fits     SCIENCE
#
#    productGroupDescription productSubGroupDescription productDocumentationURL  \
# 0                     None                        FLT                    None
# 1                     None                        FLT                    None
# 2                     None                        FLT                    None
# 3                     None                        FLT                    None
# 4                     None                        FLT                    None
# 5                     None                        FLT                    None
# 6                     None                        FLT                    None
# 7                     None                        FLT                    None
# 8                     None                        FLT                    None
# 9                     None                        FLT                    None
# 10                    None                        FLT                    None
# 11                    None                        FLT                    None
# 12                    None                        FLT                    None
# 13                    None                        FLT                    None
# 14                    None                        FLT                    None
# 15                    None                        FLT                    None
# 16                    None                        FLT                    None
# 17                    None                        FLT                    None
# 18                    None                        FLT                    None
# 19                    None                        FLT                    None
# 20                    None                        FLT                    None
# 21                    None                        FLT                    None
# 22                    None                        FLT                    None
# 23                    None                        FLT                    None
#
#    project prvversion     productFilename      size
# 0      HST       None  icka04pcq_flt.fits  16531200
# 1      HST       None  icka04pdq_flt.fits  16531200
# 2      HST       None  icka04plq_flt.fits  16531200
# 3      HST       None  icka04pnq_flt.fits  16531200
# 4      HST       None  icka05pjq_flt.fits  16531200
# 5      HST       None  icka05pkq_flt.fits  16531200
# 6      HST       None  icka05psq_flt.fits  16531200
# 7      HST       None  icka05puq_flt.fits  16531200
# 8      HST       None  icka06g7q_flt.fits  16531200
# 9      HST       None  icka06g8q_flt.fits  16531200
# 10     HST       None  icka06ggq_flt.fits  16531200
# 11     HST       None  icka06giq_flt.fits  16531200
# 12     HST       None  icka01t7q_flt.fits  16531200
# 13     HST       None  icka01t8q_flt.fits  16531200
# 14     HST       None  icka01tgq_flt.fits  16531200
# 15     HST       None  icka01tiq_flt.fits  16531200
# 16     HST       None  icka02uoq_flt.fits  16531200
# 17     HST       None  icka02upq_flt.fits  16531200
# 18     HST       None  icka02uxq_flt.fits  16531200
# 19     HST       None  icka02uzq_flt.fits  16531200
# 20     HST       None  icka03d4q_flt.fits  16531200
# 21     HST       None  icka03d5q_flt.fits  16531200
# 22     HST       None  icka03ddq_flt.fits  16531200
# 23     HST       None  icka03dfq_flt.fits  16531200

# %% [markdown]
# # Combine the two table outputs - it does this by the obsID:

# %%
all_prod_13871_grism_flts = (hstack([obsTable, flt_filter],join_type='inner'))

print all_prod_13871_grism_flts.columns
all_prod_13871_grism_flts_pandas = all_prod_13871_grism_flts.to_pandas()
print all_prod_13871_grism_flts_pandas
# Out:
# <TableColumns names=('dataproduct_type_1','calib_level','obs_collection_1','obs_id_1','target_name','s_ra','s_dec','t_min','t_max','t_exptime','wavelength_region','filters','em_min','em_max','target_classification','obs_title','t_obs_release','dataRights','mtFlag','srcDen','instrument_name','proposal_pi','proposal_id','project_1','s_region','jpegURL','dataURL','obsid','objID','obsID','obs_collection_2','dataproduct_type_2','obs_id_2','description','type','dataURI','productType','productGroupDescription','productSubGroupDescription','productDocumentationURL','project_2','prvversion','productFilename','size')>
#   dataproduct_type_1  calib_level obs_collection_1   obs_id_1 target_name  \
# 0           spectrum            3              HST  ICKA04030    GN-Z10-1
# 1           spectrum            3              HST  ICKA05030    GN-Z10-1
# 2           spectrum            3              HST  ICKA06030    GN-Z10-1
# 3           spectrum            3              HST  ICKA01030    GN-Z10-1
# 4           spectrum            3              HST  ICKA02030    GN-Z10-1
# 5           spectrum            3              HST  ICKA03030    GN-Z10-1
#
#          s_ra      s_dec        t_min        t_max    t_exptime    ...     \
# 0  189.106083  62.242056  57064.45186  57064.54036  5311.745971    ...
# 1  189.106083  62.242056  57068.83606  57068.92959  5311.745971    ...
# 2  189.106083  62.242056  57066.91493  57067.01162  5311.745971    ...
# 3  189.106083  62.242056  57107.28618  57107.43866  5311.745971    ...
# 4  189.106083  62.242056  57114.36929  57114.45788  5311.745971    ...
# 5  189.106083  62.242056  57115.84953  57115.93249  5311.745971    ...
#
#   type                                        dataURI  productType  \
# 0    S  mast:HST/product/icka04pcq/icka04pcq_flt.fits      SCIENCE
# 1    S  mast:HST/product/icka04pdq/icka04pdq_flt.fits      SCIENCE
# 2    S  mast:HST/product/icka04plq/icka04plq_flt.fits      SCIENCE
# 3    S  mast:HST/product/icka04pnq/icka04pnq_flt.fits      SCIENCE
# 4    S  mast:HST/product/icka05pjq/icka05pjq_flt.fits      SCIENCE
# 5    S  mast:HST/product/icka05pkq/icka05pkq_flt.fits      SCIENCE
#
#    productGroupDescription productSubGroupDescription productDocumentationURL  \
# 0                     None                        FLT                    None
# 1                     None                        FLT                    None
# 2                     None                        FLT                    None
# 3                     None                        FLT                    None
# 4                     None                        FLT                    None
# 5                     None                        FLT                    None
#
#    project_2 prvversion     productFilename      size
# 0        HST       None  icka04pcq_flt.fits  16531200
# 1        HST       None  icka04pdq_flt.fits  16531200
# 2        HST       None  icka04plq_flt.fits  16531200
# 3        HST       None  icka04pnq_flt.fits  16531200
# 4        HST       None  icka05pjq_flt.fits  16531200
# 5        HST       None  icka05pkq_flt.fits  16531200
#
# [6 rows x 44 columns]

# %% [markdown]
# # Now we want to get the visit numbers into the table:

# %%
visit_number = []
for curr_file in xrange(len(all_prod_13871_grism_flts_pandas['productFilename'])):
    visit_number.append(all_prod_13871_grism_flts_pandas['productFilename'][curr_file][4:6])

all_prod_13871_grism_flts_pandas['visit_number'] = visit_number

print all_prod_13871_grism_flts_pandas
# Out:
#   dataproduct_type_1  calib_level obs_collection_1   obs_id_1 target_name  \
# 0           spectrum            3              HST  ICKA04030    GN-Z10-1
# 1           spectrum            3              HST  ICKA05030    GN-Z10-1
# 2           spectrum            3              HST  ICKA06030    GN-Z10-1
# 3           spectrum            3              HST  ICKA01030    GN-Z10-1
# 4           spectrum            3              HST  ICKA02030    GN-Z10-1
# 5           spectrum            3              HST  ICKA03030    GN-Z10-1
#
#          s_ra      s_dec        t_min        t_max    t_exptime      ...       \
# 0  189.106083  62.242056  57064.45186  57064.54036  5311.745971      ...
# 1  189.106083  62.242056  57068.83606  57068.92959  5311.745971      ...
# 2  189.106083  62.242056  57066.91493  57067.01162  5311.745971      ...
# 3  189.106083  62.242056  57107.28618  57107.43866  5311.745971      ...
# 4  189.106083  62.242056  57114.36929  57114.45788  5311.745971      ...
# 5  189.106083  62.242056  57115.84953  57115.93249  5311.745971      ...
#
#                                          dataURI productType  \
# 0  mast:HST/product/icka04pcq/icka04pcq_flt.fits     SCIENCE
# 1  mast:HST/product/icka04pdq/icka04pdq_flt.fits     SCIENCE
# 2  mast:HST/product/icka04plq/icka04plq_flt.fits     SCIENCE
# 3  mast:HST/product/icka04pnq/icka04pnq_flt.fits     SCIENCE
# 4  mast:HST/product/icka05pjq/icka05pjq_flt.fits     SCIENCE
# 5  mast:HST/product/icka05pkq/icka05pkq_flt.fits     SCIENCE
#
#    productGroupDescription  productSubGroupDescription  \
# 0                     None                         FLT
# 1                     None                         FLT
# 2                     None                         FLT
# 3                     None                         FLT
# 4                     None                         FLT
# 5                     None                         FLT
#
#   productDocumentationURL project_2  prvversion     productFilename      size  \
# 0                    None       HST        None  icka04pcq_flt.fits  16531200
# 1                    None       HST        None  icka04pdq_flt.fits  16531200
# 2                    None       HST        None  icka04plq_flt.fits  16531200
# 3                    None       HST        None  icka04pnq_flt.fits  16531200
# 4                    None       HST        None  icka05pjq_flt.fits  16531200
# 5                    None       HST        None  icka05pkq_flt.fits  16531200
#
#    visit_number
# 0            04
# 1            04
# 2            04
# 3            04
# 4            05
# 5            05
#
# [6 rows x 45 columns]

# %% [markdown]
# # Split the table by visit number:

# %%
grouped_visits = all_prod_13871_grism_flts_pandas.groupby(['visit_number'])
grouped_13871_grism_flts = [grouped_visits.get_group(x) for x in grouped_visits.groups]
print grouped_13871_grism_flts
# Out:
# [  dataproduct_type_1  calib_level obs_collection_1   obs_id_1 target_name  \
# 0           spectrum            3              HST  ICKA04030    GN-Z10-1
# 1           spectrum            3              HST  ICKA05030    GN-Z10-1
# 2           spectrum            3              HST  ICKA06030    GN-Z10-1
# 3           spectrum            3              HST  ICKA01030    GN-Z10-1
#
#          s_ra      s_dec        t_min        t_max    t_exptime      ...       \
# 0  189.106083  62.242056  57064.45186  57064.54036  5311.745971      ...
# 1  189.106083  62.242056  57068.83606  57068.92959  5311.745971      ...
# 2  189.106083  62.242056  57066.91493  57067.01162  5311.745971      ...
# 3  189.106083  62.242056  57107.28618  57107.43866  5311.745971      ...
#
#                                          dataURI productType  \
# 0  mast:HST/product/icka04pcq/icka04pcq_flt.fits     SCIENCE
# 1  mast:HST/product/icka04pdq/icka04pdq_flt.fits     SCIENCE
# 2  mast:HST/product/icka04plq/icka04plq_flt.fits     SCIENCE
# 3  mast:HST/product/icka04pnq/icka04pnq_flt.fits     SCIENCE
#
#    productGroupDescription  productSubGroupDescription  \
# 0                     None                         FLT
# 1                     None                         FLT
# 2                     None                         FLT
# 3                     None                         FLT
#
#   productDocumentationURL project_2  prvversion     productFilename      size  \
# 0                    None       HST        None  icka04pcq_flt.fits  16531200
# 1                    None       HST        None  icka04pdq_flt.fits  16531200
# 2                    None       HST        None  icka04plq_flt.fits  16531200
# 3                    None       HST        None  icka04pnq_flt.fits  16531200
#
#    visit_number
# 0            04
# 1            04
# 2            04
# 3            04
#
# [4 rows x 45 columns],   dataproduct_type_1  calib_level obs_collection_1   obs_id_1 target_name  \
# 4           spectrum            3              HST  ICKA02030    GN-Z10-1
# 5           spectrum            3              HST  ICKA03030    GN-Z10-1
#
#          s_ra      s_dec        t_min        t_max    t_exptime      ...       \
# 4  189.106083  62.242056  57114.36929  57114.45788  5311.745971      ...
# 5  189.106083  62.242056  57115.84953  57115.93249  5311.745971      ...
#
#                                          dataURI productType  \
# 4  mast:HST/product/icka05pjq/icka05pjq_flt.fits     SCIENCE
# 5  mast:HST/product/icka05pkq/icka05pkq_flt.fits     SCIENCE
#
#    productGroupDescription  productSubGroupDescription  \
# 4                     None                         FLT
# 5                     None                         FLT
#
#   productDocumentationURL project_2  prvversion     productFilename      size  \
# 4                    None       HST        None  icka05pjq_flt.fits  16531200
# 5                    None       HST        None  icka05pkq_flt.fits  16531200
#
#    visit_number
# 4            05
# 5            05
#
# [2 rows x 45 columns]]

# %% [markdown]
# # S_region overlaps?
#
# I haven't figured out how to query what images overlay each other using the s_region yet (or if that is even possible) - but I figure if we do a query around the RA and DEC I can later use the s_regions to create overlays and see which overlap and how.
#
# Here I do a query with two degrees around the RA and DEC of this visit:

# %%
visit_test_one = grouped_13871_grism_flts[0]
print visit_test_one['s_dec'], visit_test_one['s_ra']
dec_one = visit_test_one['s_dec'][0]
ra_one = visit_test_one['s_ra'][0]

min_dec = dec_one - 1.0
max_dec = dec_one + 1.0

min_ra = ra_one - 1.0
max_ra = ra_one + 1.0
# Out:
# 0    62.242056
# 1    62.242056
# 2    62.242056
# 3    62.242056
# Name: s_dec, dtype: float64 0    189.106083
# 1    189.106083
# 2    189.106083
# 3    189.106083
# Name: s_ra, dtype: float64

# %%
obsTableDecRA = Observations.query_criteria(filters=["G141", "G102"],dataRights=['PUBLIC'], obs_collection = ['HST'],
                                            s_dec =[min_dec, max_dec], s_ra=[min_ra, max_ra],instrument_name=['WFC3/IR'])

# %%
print obsTableDecRA.to_pandas()
proposals = list(np.unique(obsTableDecRA['proposal_id']))
print proposals
# Out:
#     dataproduct_type  calib_level obs_collection     obs_id target_name  \
# 0           spectrum            3            HST  IB3701060   GNGRISM11
# 1           spectrum            3            HST  IB3702060   GNGRISM12
# 2           spectrum            3            HST  IB3703060   GNGRISM13
# 3           spectrum            3            HST  IB3704060   GNGRISM14
# 4           spectrum            3            HST  IB3705060   GNGRISM21
# 5           spectrum            3            HST  IB3706060   GNGRISM22
# 6           spectrum            3            HST  IB3707060   GNGRISM23
# 7           spectrum            3            HST  IB3708060   GNGRISM24
# 8           spectrum            3            HST  IB3709060   GNGRISM31
# 9           spectrum            3            HST  IB3710060   GNGRISM32
# 10          spectrum            3            HST  IB3711060   GNGRISM33
# 11          spectrum            3            HST  IB3712060   GNGRISM34
# 12          spectrum            3            HST  IB3713060   GNGRISM41
# 13          spectrum            3            HST  IB3714060   GNGRISM42
# 14          spectrum            3            HST  IB3715060   GNGRISM43
# 15          spectrum            3            HST  IB3716060   GNGRISM44
# 16          spectrum            3            HST  IB3717060   GNGRISM15
# 17          spectrum            3            HST  IB3718060   GNGRISM16
# 18          spectrum            3            HST  IB3719060   GNGRISM17
# 19          spectrum            3            HST  IB3720060   GNGRISM18
# 20          spectrum            3            HST  IB3721060   GNGRISM25
# 21          spectrum            3            HST  IB3722060   GNGRISM26
# 22          spectrum            3            HST  IB3723060   GNGRISM27
# 23          spectrum            3            HST  IB3724060   GNGRISM28
# 24          spectrum            3            HST  IB3725060   GNGRISM35
# 25          spectrum            3            HST  IB3726060   GNGRISM36
# 26          spectrum            3            HST  IB3727060   GNGRISM45
# 27          spectrum            3            HST  IB3728060   GNGRISM46
# 28          spectrum            3            HST  IB3741030   GNGRISM11
# 29          spectrum            3            HST  IB3742030   GNGRISM12
# ..               ...          ...            ...        ...         ...
# 114         spectrum            3            HST  ICOI4L030    FIGS-GN2
# 115         spectrum            3            HST  ICXT44010         GN5
# 116         spectrum            3            HST  ICXT45010         GN5
# 117         spectrum            3            HST  ICXT39010         GN7
# 118         spectrum            3            HST  ICXT40010         GN7
# 119         spectrum            3            HST  ICXT54010         GN2
# 120         spectrum            3            HST  ICXT41010         GN5
# 121         spectrum            3            HST  ICXT55010         GN2
# 122         spectrum            3            HST  ICXT36020         GN7
# 123         spectrum            3            HST  ICXT51020         GN2
# 124         spectrum            3            HST  ICXT42020         GN5
# 125         spectrum            3            HST  ICXT43020         GN5
# 126         spectrum            3            HST  ICXT37010         GN7
# 127         spectrum            3            HST  ICXT38010         GN7
# 128         spectrum            3            HST  ICXT52010         GN2
# 129         spectrum            3            HST  ICXT53010         GN2
# 130         spectrum            3            HST  ICXT64020         GN4
# 131         spectrum            3            HST  ICXT65020         GN4
# 132         spectrum            3            HST  ICXT49020         GN1
# 133         spectrum            3            HST  ICXT50020         GN1
# 134         spectrum            3            HST  ICXT59020         GN3
# 135         spectrum            3            HST  ICXT60020         GN3
# 136         spectrum            3            HST  ICXT61010         GN4
# 137         spectrum            3            HST  ICXT46010         GN1
# 138         spectrum            3            HST  ICXT56010         GN3
# 139         spectrum            3            HST  ICXT47020         GN1
# 140         spectrum            3            HST  ICXT48020         GN1
# 141         spectrum            3            HST  ICXT57020         GN3
# 142         spectrum            3            HST  ICXT58020         GN3
# 143         spectrum            3            HST  ICXTA4010         GN2
#
#            s_ra      s_dec        t_min        t_max    t_exptime     ...      \
# 0    188.979083  62.197583  55301.10619  55301.23662  5311.745971     ...
# 1    189.026792  62.219806  55301.79376  55301.89576  5311.745971     ...
# 2    189.074542  62.242056  55301.94632  55302.03299  5311.745971     ...
# 3    189.122208  62.264278  55302.08690  55302.17272  5311.745971     ...
# 4    189.033542  62.172222  55302.28067  55302.35926  5311.745971     ...
# 5    189.081250  62.194444  55302.94433  55303.03128  5311.745971     ...
# 6    189.128958  62.216667  55303.08522  55303.17096  5311.745971     ...
# 7    189.176667  62.238917  55303.87303  55303.95973  5311.745971     ...
# 8    189.088000  62.146833  55304.00479  55304.09941  5311.745971     ...
# 9    189.135750  62.169056  55304.67942  55304.79758  5311.745971     ...
# 10   189.183417  62.191306  55305.14332  55305.32655  5311.745971     ...
# 11   189.231167  62.213528  55306.65207  55306.74375  5311.745971     ...
# 12   189.142458  62.121444  55262.72147  55262.91973  5311.745971     ...
# 13   189.190208  62.143694  55305.80706  55305.93778  5311.745971     ...
# 14   189.237875  62.165917  55307.71589  55307.81275  5311.745971     ...
# 15   189.285625  62.188139  55307.20250  55307.34431  5311.745971     ...
# 16   189.169917  62.286528  55308.44737  55308.54296  5311.745971     ...
# 17   189.217583  62.308750  55464.88263  55464.99955  5311.745971     ...
# 18   189.265333  62.330972  55097.54677  55097.69234  5311.745971     ...
# 19   189.313042  62.353194  55465.72499  55465.81532  5311.745971     ...
# 20   189.224375  62.261139  55308.58046  55308.67613  5311.745971     ...
# 21   189.272083  62.283361  55460.87133  55460.96561  5311.745971     ...
# 22   189.319792  62.305611  55090.14716  55090.23906  5311.745971     ...
# 23   189.367500  62.327833  55090.28007  55090.37216  5311.745971     ...
# 24   189.278833  62.235750  55099.14333  55099.27086  5311.745971     ...
# 25   189.326542  62.258000  55309.33053  55309.45654  5311.745971     ...
# 26   189.333292  62.210389  55295.04734  55295.25490  5311.745971     ...
# 27   189.381042  62.232611  55309.51153  55309.60825  5311.745971     ...
# 28   188.979344  62.197456  55670.63009  55670.65981  2505.872436     ...
# 29   189.027053  62.219678  55675.09190  55675.16811  2505.872436     ...
# ..          ...        ...          ...          ...          ...     ...
# 114  189.389987  62.308059  57371.80442  57371.90020  5023.500244     ...
# 115  189.166173  62.322861  57420.57778  57420.66905  4711.743774     ...
# 116  189.166173  62.322861  57420.71010  57420.80148  4711.743774     ...
# 117  189.128869  62.220900  57451.86463  57451.95448  4711.743774     ...
# 118  189.128869  62.220900  57452.79096  57452.87844  4711.743774     ...
# 119  189.219865  62.244391  57453.71794  57453.80608  4711.743774     ...
# 120  189.160176  62.323193  57454.84356  57454.93473  4711.743774     ...
# 121  189.219865  62.244391  57455.83671  57455.92812  4711.743774     ...
# 122  189.124256  62.219469  57483.44942  57483.54319  4711.743774     ...
# 123  189.214464  62.243342  57483.58747  57483.67560  4711.743774     ...
# 124  189.156181  62.322280  57487.28887  57487.38264  4711.743774     ...
# 125  189.156181  62.322280  57488.28169  57488.37553  4711.743774     ...
# 126  189.122712  62.218163  57504.66760  57504.75532  4711.743774     ...
# 127  189.122712  62.218163  57505.59422  57505.68284  4711.743774     ...
# 128  189.211538  62.241056  57509.49777  57509.59130  4711.743774     ...
# 129  189.211538  62.241056  57509.63203  57509.72375  4711.743774     ...
# 130  189.299661  62.259780  57625.43052  57625.52240  4711.743774     ...
# 131  189.299661  62.259780  57628.27700  57628.36632  4711.743774     ...
# 132  189.305256  62.359737  57630.19256  57630.28634  4711.743774     ...
# 133  189.305256  62.359737  57630.32927  57630.41876  4711.743774     ...
# 134  189.251706  62.311397  57642.04396  57642.13706  4711.743774     ...
# 135  189.251706  62.311397  57642.17635  57642.26946  4711.743774     ...
# 136  189.305892  62.260246  57662.62278  57662.69991  4711.743774     ...
# 137  189.311429  62.360389  57668.15267  57668.24745  4711.743774     ...
# 138  189.255476  62.311996  57668.29990  57668.37984  4711.743774     ...
# 139  189.313787  62.361403  57690.13692  57690.22862  4711.743774     ...
# 140  189.313787  62.361403  57687.95223  57688.04473  4711.743774     ...
# 141  189.258271  62.313221  57691.06374  57691.15544  4711.743774     ...
# 142  189.258271  62.313221  57692.05677  57692.14846  4711.743774     ...
# 143  189.219865  62.244391  57803.78955  57803.88307  4711.743774     ...
#
#     srcDen instrument_name  proposal_pi  proposal_id project  \
# 0      NaN         WFC3/IR       Weiner        11600     HST
# 1      NaN         WFC3/IR       Weiner        11600     HST
# 2      NaN         WFC3/IR       Weiner        11600     HST
# 3      NaN         WFC3/IR       Weiner        11600     HST
# 4      NaN         WFC3/IR       Weiner        11600     HST
# 5      NaN         WFC3/IR       Weiner        11600     HST
# 6      NaN         WFC3/IR       Weiner        11600     HST
# 7      NaN         WFC3/IR       Weiner        11600     HST
# 8      NaN         WFC3/IR       Weiner        11600     HST
# 9      NaN         WFC3/IR       Weiner        11600     HST
# 10     NaN         WFC3/IR       Weiner        11600     HST
# 11     NaN         WFC3/IR       Weiner        11600     HST
# 12     NaN         WFC3/IR       Weiner        11600     HST
# 13     NaN         WFC3/IR       Weiner        11600     HST
# 14     NaN         WFC3/IR       Weiner        11600     HST
# 15     NaN         WFC3/IR       Weiner        11600     HST
# 16     NaN         WFC3/IR       Weiner        11600     HST
# 17     NaN         WFC3/IR       Weiner        11600     HST
# 18     NaN         WFC3/IR       Weiner        11600     HST
# 19     NaN         WFC3/IR       Weiner        11600     HST
# 20     NaN         WFC3/IR       Weiner        11600     HST
# 21     NaN         WFC3/IR       Weiner        11600     HST
# 22     NaN         WFC3/IR       Weiner        11600     HST
# 23     NaN         WFC3/IR       Weiner        11600     HST
# 24     NaN         WFC3/IR       Weiner        11600     HST
# 25     NaN         WFC3/IR       Weiner        11600     HST
# 26     NaN         WFC3/IR       Weiner        11600     HST
# 27     NaN         WFC3/IR       Weiner        11600     HST
# 28     NaN         WFC3/IR       Weiner        11600     HST
# 29     NaN         WFC3/IR       Weiner        11600     HST
# ..     ...             ...          ...          ...     ...
# 114    NaN         WFC3/IR     Malhotra        13779     HST
# 115    NaN         WFC3/IR     Papovich        14227     HST
# 116    NaN         WFC3/IR     Papovich        14227     HST
# 117    NaN         WFC3/IR     Papovich        14227     HST
# 118    NaN         WFC3/IR     Papovich        14227     HST
# 119    NaN         WFC3/IR     Papovich        14227     HST
# 120    NaN         WFC3/IR     Papovich        14227     HST
# 121    NaN         WFC3/IR     Papovich        14227     HST
# 122    NaN         WFC3/IR     Papovich        14227     HST
# 123    NaN         WFC3/IR     Papovich        14227     HST
# 124    NaN         WFC3/IR     Papovich        14227     HST
# 125    NaN         WFC3/IR     Papovich        14227     HST
# 126    NaN         WFC3/IR     Papovich        14227     HST
# 127    NaN         WFC3/IR     Papovich        14227     HST
# 128    NaN         WFC3/IR     Papovich        14227     HST
# 129    NaN         WFC3/IR     Papovich        14227     HST
# 130    NaN         WFC3/IR     Papovich        14227     HST
# 131    NaN         WFC3/IR     Papovich        14227     HST
# 132    NaN         WFC3/IR     Papovich        14227     HST
# 133    NaN         WFC3/IR     Papovich        14227     HST
# 134    NaN         WFC3/IR     Papovich        14227     HST
# 135    NaN         WFC3/IR     Papovich        14227     HST
# 136    NaN         WFC3/IR     Papovich        14227     HST
# 137    NaN         WFC3/IR     Papovich        14227     HST
# 138    NaN         WFC3/IR     Papovich        14227     HST
# 139    NaN         WFC3/IR     Papovich        14227     HST
# 140    NaN         WFC3/IR     Papovich        14227     HST
# 141    NaN         WFC3/IR     Papovich        14227     HST
# 142    NaN         WFC3/IR     Papovich        14227     HST
# 143    NaN         WFC3/IR     Papovich        14227     HST
#
#                                               s_region  \
# 0    POLYGON -170.96938183999998 62.20174028 -171.0...
# 1    POLYGON -170.92170848 62.22415487 -170.9936149...
# 2    POLYGON -170.87392052 62.24640496 -170.9458802...
# 3    POLYGON -170.82683977 62.27000459 -170.9011183...
# 4    POLYGON -170.91503954 62.17657156 -170.9868328...
# 5    POLYGON -170.86729349 62.198794 -170.93913998 ...
# 6    POLYGON -170.82080280000002 62.22350131 -170.8...
# 7    POLYGON -170.77180089 62.24326607 -170.8437531...
# 8    POLYGON -170.86062438 62.15118278 -170.9323576...
# 9    POLYGON -170.81283663 62.17340499 -170.8846225...
# 10   POLYGON -170.76513210999997 62.19565498 -170.8...
# 11   POLYGON -170.71734430000004 62.21787733 -170.7...
# 12   POLYGON -170.80844501 62.113211 -170.84993097 ...
# 13   POLYGON -170.75842137 62.14804389 -170.8301471...
# 14   POLYGON -170.71071697000002 62.1702661 -170.78...
# 15   POLYGON -170.66241273000003 62.19083358 -170.7...
# 16   POLYGON -170.77846933 62.29087706 -170.8505352...
# 17   POLYGON -170.72571441000002 62.3044966 -170.77...
# 18   POLYGON -170.67808479 62.32613115 -170.7259783...
# 19   POLYGON -170.63005498999996 62.34929169 -170.6...
# 20   POLYGON -170.72405449999997 62.26548818 -170.7...
# 21   POLYGON -170.67209417000004 62.277173 -170.716...
# 22   POLYGON -170.62453070000004 62.29896585 -170.6...
# 23   POLYGON -170.57675799000003 62.32123012 -170.6...
# 24   POLYGON -170.66464344999997 62.23122214 -170.7...
# 25   POLYGON -170.62189324999997 62.26234939 -170.6...
# 26   POLYGON -170.61442141999999 62.20955145 -170.6...
# 27   POLYGON -170.56743672 62.23696065 -170.6393741...
# 28   POLYGON -170.96919418 62.20180528 -171.0410474...
# 29   POLYGON -170.92144775999998 62.22402749 -170.9...
# ..                                                 ...
# 114  POLYGON -170.55617547999998 62.30384457 -170.5...
# 115  POLYGON -170.79515663 62.34078787 -170.8681638...
# 116  POLYGON -170.79515663 62.34078787 -170.8681638...
# 117  POLYGON -170.82053881000002 62.21465388 -170.8...
# 118  POLYGON -170.82053865 62.2146542 -170.86825589...
# 119  POLYGON -170.7334019 62.23337913 -170.76599806...
# 120  POLYGON -170.7900848 62.31536977 -170.83325982...
# 121  POLYGON -170.73340186999997 62.23337916 -170.7...
# 122  POLYGON -170.82660698 62.22788032 -170.9045954...
# 123  POLYGON -170.73397381 62.24764865 -170.8059418...
# 124  POLYGON -170.79196819000003 62.32616632 -170.8...
# 125  POLYGON -170.79196829 62.32616655 -170.8633911...
# 126  POLYGON -170.83791281000003 62.1998301 -170.83...
# 127  POLYGON -170.83791281000003 62.1998301 -170.83...
# 128  POLYGON -170.74509089000003 62.22478132 -170.7...
# 129  POLYGON -170.74509089000003 62.22478132 -170.7...
# 130  POLYGON -170.6553781 62.24321287 -170.66681030...
# 131  POLYGON -170.6553781 62.24321287 -170.66681030...
# 132  POLYGON -170.64742386 62.34455427 -170.6640590...
# 133  POLYGON -170.64742386 62.34455427 -170.6640590...
# 134  POLYGON -170.69468923 62.3018022 -170.72950286...
# 135  POLYGON -170.69468923 62.3018022 -170.72950286...
# 136  POLYGON -170.63677624000002 62.26100577 -170.6...
# 137  POLYGON -170.63127148 62.36286874 -170.6951452...
# 138  POLYGON -170.68719737000004 62.31377911 -170.7...
# 139  POLYGON -170.63418823999996 62.37282424 -170.7...
# 140  POLYGON -170.63418823999996 62.37282424 -170.7...
# 141  POLYGON -170.69090809 62.32568441 -170.7690270...
# 142  POLYGON -170.69090809 62.32568441 -170.7690270...
# 143  POLYGON -170.73340207 62.23337896 -170.7659976...
#
#                                           jpegURL  \
# 0    mast:HST/product/ib3701060/ib3701060_drz.jpg
# 1    mast:HST/product/ib3702060/ib3702060_drz.jpg
# 2    mast:HST/product/ib3703060/ib3703060_drz.jpg
# 3    mast:HST/product/ib3704060/ib3704060_drz.jpg
# 4    mast:HST/product/ib3705060/ib3705060_drz.jpg
# 5    mast:HST/product/ib3706060/ib3706060_drz.jpg
# 6    mast:HST/product/ib3707060/ib3707060_drz.jpg
# 7    mast:HST/product/ib3708060/ib3708060_drz.jpg
# 8    mast:HST/product/ib3709060/ib3709060_drz.jpg
# 9    mast:HST/product/ib3710060/ib3710060_drz.jpg
# 10   mast:HST/product/ib3711060/ib3711060_drz.jpg
# 11   mast:HST/product/ib3712060/ib3712060_drz.jpg
# 12   mast:HST/product/ib3713060/ib3713060_drz.jpg
# 13   mast:HST/product/ib3714060/ib3714060_drz.jpg
# 14   mast:HST/product/ib3715060/ib3715060_drz.jpg
# 15   mast:HST/product/ib3716060/ib3716060_drz.jpg
# 16   mast:HST/product/ib3717060/ib3717060_drz.jpg
# 17   mast:HST/product/ib3718060/ib3718060_drz.jpg
# 18   mast:HST/product/ib3719060/ib3719060_drz.jpg
# 19   mast:HST/product/ib3720060/ib3720060_drz.jpg
# 20   mast:HST/product/ib3721060/ib3721060_drz.jpg
# 21   mast:HST/product/ib3722060/ib3722060_drz.jpg
# 22   mast:HST/product/ib3723060/ib3723060_drz.jpg
# 23   mast:HST/product/ib3724060/ib3724060_drz.jpg
# 24   mast:HST/product/ib3725060/ib3725060_drz.jpg
# 25   mast:HST/product/ib3726060/ib3726060_drz.jpg
# 26   mast:HST/product/ib3727060/ib3727060_drz.jpg
# 27   mast:HST/product/ib3728060/ib3728060_drz.jpg
# 28   mast:HST/product/ib3741030/ib3741030_drz.jpg
# 29   mast:HST/product/ib3742030/ib3742030_drz.jpg
# ..                                            ...
# 114  mast:HST/product/icoi4l030/icoi4l030_drz.jpg
# 115  mast:HST/product/icxt44010/icxt44010_drz.jpg
# 116  mast:HST/product/icxt45010/icxt45010_drz.jpg
# 117  mast:HST/product/icxt39010/icxt39010_drz.jpg
# 118  mast:HST/product/icxt40010/icxt40010_drz.jpg
# 119  mast:HST/product/icxt54010/icxt54010_drz.jpg
# 120  mast:HST/product/icxt41010/icxt41010_drz.jpg
# 121  mast:HST/product/icxt55010/icxt55010_drz.jpg
# 122  mast:HST/product/icxt36020/icxt36020_drz.jpg
# 123  mast:HST/product/icxt51020/icxt51020_drz.jpg
# 124  mast:HST/product/icxt42020/icxt42020_drz.jpg
# 125  mast:HST/product/icxt43020/icxt43020_drz.jpg
# 126  mast:HST/product/icxt37010/icxt37010_drz.jpg
# 127  mast:HST/product/icxt38010/icxt38010_drz.jpg
# 128  mast:HST/product/icxt52010/icxt52010_drz.jpg
# 129  mast:HST/product/icxt53010/icxt53010_drz.jpg
# 130  mast:HST/product/icxt64020/icxt64020_drz.jpg
# 131  mast:HST/product/icxt65020/icxt65020_drz.jpg
# 132  mast:HST/product/icxt49020/icxt49020_drz.jpg
# 133  mast:HST/product/icxt50020/icxt50020_drz.jpg
# 134  mast:HST/product/icxt59020/icxt59020_drz.jpg
# 135  mast:HST/product/icxt60020/icxt60020_drz.jpg
# 136  mast:HST/product/icxt61010/icxt61010_drz.jpg
# 137  mast:HST/product/icxt46010/icxt46010_drz.jpg
# 138  mast:HST/product/icxt56010/icxt56010_drz.jpg
# 139  mast:HST/product/icxt47020/icxt47020_drz.jpg
# 140  mast:HST/product/icxt48020/icxt48020_drz.jpg
# 141  mast:HST/product/icxt57020/icxt57020_drz.jpg
# 142  mast:HST/product/icxt58020/icxt58020_drz.jpg
# 143  mast:HST/product/icxta4010/icxta4010_drz.jpg
#
#                          dataURL       obsid       objID
# 0    mast:HST/exposure/ib3701060  2003839729  2012905093
# 1    mast:HST/exposure/ib3702060  2003839731  2012905095
# 2    mast:HST/exposure/ib3703060  2003839733  2012905097
# 3    mast:HST/exposure/ib3704060  2003839735  2012905099
# 4    mast:HST/exposure/ib3705060  2003839737  2012905101
# 5    mast:HST/exposure/ib3706060  2003839739  2012905103
# 6    mast:HST/exposure/ib3707060  2003839741  2012905105
# 7    mast:HST/exposure/ib3708060  2003839743  2012905107
# 8    mast:HST/exposure/ib3709060  2003839745  2012905109
# 9    mast:HST/exposure/ib3710060  2003839747  2012905111
# 10   mast:HST/exposure/ib3711060  2003839749  2012905113
# 11   mast:HST/exposure/ib3712060  2003839751  2012905115
# 12   mast:HST/exposure/ib3713060  2003839753  2012905117
# 13   mast:HST/exposure/ib3714060  2003839755  2012905119
# 14   mast:HST/exposure/ib3715060  2003839757  2012905121
# 15   mast:HST/exposure/ib3716060  2003839759  2012905123
# 16   mast:HST/exposure/ib3717060  2003839761  2012905125
# 17   mast:HST/exposure/ib3718060  2003839763  2012905127
# 18   mast:HST/exposure/ib3719060  2003839765  2012905129
# 19   mast:HST/exposure/ib3720060  2003839767  2012905131
# 20   mast:HST/exposure/ib3721060  2003839769  2012905133
# 21   mast:HST/exposure/ib3722060  2003839771  2012905135
# 22   mast:HST/exposure/ib3723060  2003839773  2012905137
# 23   mast:HST/exposure/ib3724060  2003839775  2012905139
# 24   mast:HST/exposure/ib3725060  2003839777  2012905141
# 25   mast:HST/exposure/ib3726060  2003839779  2012905143
# 26   mast:HST/exposure/ib3727060  2003839781  2012905145
# 27   mast:HST/exposure/ib3728060  2003839783  2012905147
# 28   mast:HST/exposure/ib3741030  2003839784  2012905148
# 29   mast:HST/exposure/ib3742030  2003839785  2012905149
# ..                           ...         ...         ...
# 114  mast:HST/exposure/icoi4l030  2004374598  2014315526
# 115  mast:HST/exposure/icxt44010  2004618237  2015052528
# 116  mast:HST/exposure/icxt45010  2004618239  2015052530
# 117  mast:HST/exposure/icxt39010  2004622381  2015061630
# 118  mast:HST/exposure/icxt40010  2004622383  2015061632
# 119  mast:HST/exposure/icxt54010  2004622385  2015061634
# 120  mast:HST/exposure/icxt41010  2004623272  2015063724
# 121  mast:HST/exposure/icxt55010  2004623274  2015063726
# 122  mast:HST/exposure/icxt36020  2004626804  2015071853
# 123  mast:HST/exposure/icxt51020  2004626806  2015071855
# 124  mast:HST/exposure/icxt42020  2004627432  2015073395
# 125  mast:HST/exposure/icxt43020  2004627434  2015073397
# 126  mast:HST/exposure/icxt37010  2004630047  2015079275
# 127  mast:HST/exposure/icxt38010  2004630049  2015079277
# 128  mast:HST/exposure/icxt52010  2004630051  2015079279
# 129  mast:HST/exposure/icxt53010  2004631057  2015081559
# 130  mast:HST/exposure/icxt64020  2004655824  2015121991
# 131  mast:HST/exposure/icxt65020  2004656324  2015123095
# 132  mast:HST/exposure/icxt49020  2004656863  2015124161
# 133  mast:HST/exposure/icxt50020  2004656865  2015124163
# 134  mast:HST/exposure/icxt59020  2004658446  2015127678
# 135  mast:HST/exposure/icxt60020  2004658448  2015127680
# 136  mast:HST/exposure/icxt61010  2004661364  2015134215
# 137  mast:HST/exposure/icxt46010  2004662710  2015136904
# 138  mast:HST/exposure/icxt56010  2004662712  2015136906
# 139  mast:HST/exposure/icxt47020  2004665443  2015143039
# 140  mast:HST/exposure/icxt48020  2004665445  2015143041
# 141  mast:HST/exposure/icxt57020  2004665447  2015143043
# 142  mast:HST/exposure/icxt58020  2004665449  2015143045
# 143  mast:HST/exposure/icxta4010  2006929725  2017366547
#
# [144 rows x 29 columns]
# ['11600', '12461', '13420', '13779', '13871', '14227']

# %% [markdown]
# # Direct images that overlap with our visit:

# %%
obsTableDecRA_directimages = Observations.query_criteria(dataproduct_type=['image'],dataRights=['PUBLIC'], obs_collection = ['HST'],
                                            s_dec =[min_dec, max_dec], s_ra=[min_ra, max_ra])
#obsTableProductsDecRA_directimages = Observations.get_product_list(obsTableDecRA_directimages)

# %%
#all_prod_directimage = (hstack([obsTableDecRA_directimages, obsTableProductsDecRA_directimagesDecRA],join_type='inner'))
#all_DecRA_directimages_pandas = all_prod_directimage.to_pandas()
obsTableDecRA_directimages_pandas = obsTableDecRA_directimages.to_pandas()

# %%
print np.unique(obsTableDecRA_directimages_pandas['filters'])
print np.unique(obsTableDecRA_directimages_pandas['proposal_id'])
print(obsTableDecRA_directimages_pandas.loc[obsTableDecRA_directimages_pandas['proposal_id'] == '13871'])
# Out:
# ['F098M' 'F105W' 'F108N' 'F110W' 'F113N' 'F125W' 'F127M' 'F139M' 'F140W'
#  'F150LP;F150LP' 'F153M' 'F160W' 'F164N' 'F166N' 'F187N' 'F190N' 'F196N'
#  'F200LP' 'F200N' 'F205W' 'F212N' 'F215N' 'F220W' 'F222M' 'F237M' 'F240M'
#  'F275W' 'F300W' 'F336W' 'F350LP' 'F435W' 'F438W' 'F450W' 'F475W' 'F547M'
#  'F555W' 'F555W;F606W' 'F606W' 'F625W' 'F657N' 'F658N' 'F675W' 'F702W'
#  'F763M' 'F775W' 'F814W' 'F814W;F791W' 'F845M' 'F850LP' 'F892N' 'MIRFUV'
#  'MIRNUV' 'MIRVIS']
# ['10000' '10085' '10096' '10189' '10339' '10491' '10530' '10872' '11082'
#  '11143' '11144' '11191' '11192' '11594' '11600' '12166' '12442' '12443'
#  '12444' '12445' '12461' '12479' '12960' '13063' '13364' '13420' '13773'
#  '13779' '13871' '13872' '14227' '14258' '4804' '6254' '6313' '6337' '6340'
#  '6363' '6473' '6802' '7048' '7203' '7235' '7410' '7452' '7588' '7675'
#  '7676' '7701' '7714' '7781' '7782' '7783' '7786' '7807' '7815' '7817'
#  '7883' '7900' '7907' '7908' '7909' '7910' '7918' '7919' '7920' '7921'
#  '7922' '8013' '8057' '8062' '8064' '8084' '8090' '8187' '8260' '8389'
#  '8406' '8470' '8549' '8561' '8562' '8805' '9066' '9174' '9269' '9301'
#  '9317' '9318' '9352' '9468' '9478' '9480' '9481' '9484' '9488' '9575'
#  '9583' '9584' '9677' '9692' '9699' '9706' '9708' '9710' '9712' '9727'
#  '9728' '9771' '9856' '9865' '9984']
#      dataproduct_type  calib_level obs_collection     obs_id target_name  \
# 6229            image            3            HST  ICKA04020    GN-Z10-1
# 6230            image            3            HST  ICKA05020    GN-Z10-1
# 6231            image            3            HST  ICKA06020    GN-Z10-1
# 7298            image            3            HST  JCKA04010         ANY
# 7299            image            3            HST  JCKA05010         ANY
# 7300            image            3            HST  JCKA06010         ANY
# 8095            image            3            HST  ICKA01020    GN-Z10-1
# 8096            image            3            HST  ICKA02020    GN-Z10-1
# 8097            image            3            HST  ICKA03020    GN-Z10-1
# 8101            image            3            HST  JCKA01010         ANY
# 8102            image            3            HST  JCKA02010         ANY
# 8103            image            3            HST  JCKA03010         ANY
#
#             s_ra      s_dec        t_min        t_max    t_exptime  \
# 6229  189.106083  62.242056  57064.44911  57064.54252   711.734956
# 6230  189.106083  62.242056  57068.83331  57068.93176   711.734956
# 6231  189.106083  62.242056  57066.91218  57067.01378   711.734956
# 7298  189.310823  62.258330  57064.44985  57064.54122  5696.000000
# 7299  189.310823  62.258330  57068.83405  57068.93045  5696.000000
# 7300  189.310823  62.258330  57066.91292  57067.01248  5696.000000
# 8095  189.106083  62.242056  57107.28343  57107.44082   711.734956
# 8096  189.106083  62.242056  57114.36654  57114.46005   711.734956
# 8097  189.106083  62.242056  57115.84677  57115.93465   711.734956
# 8101  189.261262  62.306401  57107.28417  57107.43953  5696.000000
# 8102  189.261262  62.306401  57114.36728  57114.45874  5696.000000
# 8103  189.261262  62.306401  57115.84751  57115.93336  5696.000000
#
#          ...     srcDen instrument_name  proposal_pi  proposal_id project  \
# 6229     ...        NaN         WFC3/IR        Oesch        13871     HST
# 6230     ...        NaN         WFC3/IR        Oesch        13871     HST
# 6231     ...        NaN         WFC3/IR        Oesch        13871     HST
# 7298     ...        NaN         ACS/WFC        Oesch        13871     HST
# 7299     ...        NaN         ACS/WFC        Oesch        13871     HST
# 7300     ...        NaN         ACS/WFC        Oesch        13871     HST
# 8095     ...        NaN         WFC3/IR        Oesch        13871     HST
# 8096     ...        NaN         WFC3/IR        Oesch        13871     HST
# 8097     ...        NaN         WFC3/IR        Oesch        13871     HST
# 8101     ...        NaN         ACS/WFC        Oesch        13871     HST
# 8102     ...        NaN         ACS/WFC        Oesch        13871     HST
# 8103     ...        NaN         ACS/WFC        Oesch        13871     HST
#
#                                                s_region  \
# 6229  POLYGON -170.85255809 62.22709301 -170.8699934...
# 6230  POLYGON -170.85255813000003 62.22709299 -170.8...
# 6231  POLYGON -170.85255809 62.22709301 -170.8699934...
# 7298  POLYGON -170.60361099 62.26985424 -170.7042711...
# 7299  POLYGON -170.60361099 62.26985424 -170.7042711...
# 7300  POLYGON -170.60361099 62.26985424 -170.7042711...
# 8095  POLYGON -170.84181203000003 62.23957431 -170.8...
# 8096  POLYGON -170.84181203000003 62.23957437 -170.8...
# 8097  POLYGON -170.84181206 62.23957415 -170.8995903...
# 8101  POLYGON -170.67820878999999 62.27975932 -170.6...
# 8102  POLYGON -170.67820878999999 62.27975932 -170.6...
# 8103  POLYGON -170.67820878999999 62.27975932 -170.6...
#
#                                            jpegURL  \
# 6229  mast:HST/product/icka04020/icka04020_drz.jpg
# 6230  mast:HST/product/icka05020/icka05020_drz.jpg
# 6231  mast:HST/product/icka06020/icka06020_drz.jpg
# 7298  mast:HST/product/jcka04010/jcka04010_drz.jpg
# 7299  mast:HST/product/jcka05010/jcka05010_drz.jpg
# 7300  mast:HST/product/jcka06010/jcka06010_drz.jpg
# 8095  mast:HST/product/icka01020/icka01020_drz.jpg
# 8096  mast:HST/product/icka02020/icka02020_drz.jpg
# 8097  mast:HST/product/icka03020/icka03020_drz.jpg
# 8101  mast:HST/product/jcka01010/jcka01010_drz.jpg
# 8102  mast:HST/product/jcka02010/jcka02010_drz.jpg
# 8103  mast:HST/product/jcka03010/jcka03010_drz.jpg
#
#                           dataURL       obsid       objID
# 6229  mast:HST/exposure/icka04020  2003858742  2012924106
# 6230  mast:HST/exposure/icka05020  2003858744  2012924108
# 6231  mast:HST/exposure/icka06020  2003858746  2012924110
# 7298  mast:HST/exposure/jcka04010  2003883011  2012948375
# 7299  mast:HST/exposure/jcka05010  2003883012  2012948376
# 7300  mast:HST/exposure/jcka06010  2003883013  2012948377
# 8095  mast:HST/exposure/icka01020  2004305737  2014141760
# 8096  mast:HST/exposure/icka02020  2004305739  2014141762
# 8097  mast:HST/exposure/icka03020  2004305741  2014141764
# 8101  mast:HST/exposure/jcka01010  2004306096  2014142119
# 8102  mast:HST/exposure/jcka02010  2004306097  2014142120
# 8103  mast:HST/exposure/jcka03010  2004306098  2014142121
#
# [12 rows x 29 columns]

# %% [markdown]
# It takes too long to download all the products for all the direct images that match the above, it's also obvious from the various dataURL which of these rows match with our Visit 04 from our original searches - but it's not using the same naming convention that the flt files do.
#
# Another way to check is to use the t_min and t_max of the direct images in comparison with the grism images:

# %%
print "t_min of grism data: "
print visit_test_one['t_min']

print "t_max of grism data: "
print visit_test_one['t_max']
# Out:
# t_min of grism data:
# 0    57064.45186
# 1    57068.83606
# 2    57066.91493
# 3    57107.28618
# Name: t_min, dtype: float64
# t_max of grism data:
# 0    57064.54036
# 1    57068.92959
# 2    57067.01162
# 3    57107.43866
# Name: t_max, dtype: float64

# %%
direct_images_of_our_prop = obsTableDecRA_directimages_pandas.loc[obsTableDecRA_directimages_pandas['proposal_id'] == '13871']
print "t_min of direct data: "
print direct_images_of_our_prop['t_min']

print "t_max of direct data: "
print direct_images_of_our_prop['t_max']
# Out:
# t_min of direct data:
# 6229    57064.44911
# 6230    57068.83331
# 6231    57066.91218
# 7298    57064.44985
# 7299    57068.83405
# 7300    57066.91292
# 8095    57107.28343
# 8096    57114.36654
# 8097    57115.84677
# 8101    57107.28417
# 8102    57114.36728
# 8103    57115.84751
# Name: t_min, dtype: float64
# t_max of direct data:
# 6229    57064.54252
# 6230    57068.93176
# 6231    57067.01378
# 7298    57064.54122
# 7299    57068.93045
# 7300    57067.01248
# 8095    57107.44082
# 8096    57114.46005
# 8097    57115.93465
# 8101    57107.43953
# 8102    57114.45874
# 8103    57115.93336
# Name: t_max, dtype: float64

# %%
print visit_test_one['dataURL']
print direct_images_of_our_prop['dataURL']
# Out:
# 0    mast:HST/exposure/icka04030
# 1    mast:HST/exposure/icka05030
# 2    mast:HST/exposure/icka06030
# 3    mast:HST/exposure/icka01030
# Name: dataURL, dtype: object
# 6229    mast:HST/exposure/icka04020
# 6230    mast:HST/exposure/icka05020
# 6231    mast:HST/exposure/icka06020
# 7298    mast:HST/exposure/jcka04010
# 7299    mast:HST/exposure/jcka05010
# 7300    mast:HST/exposure/jcka06010
# 8095    mast:HST/exposure/icka01020
# 8096    mast:HST/exposure/icka02020
# 8097    mast:HST/exposure/icka03020
# 8101    mast:HST/exposure/jcka01010
# 8102    mast:HST/exposure/jcka02010
# 8103    mast:HST/exposure/jcka03010
# Name: dataURL, dtype: object

# %%
direct_image_tmin = direct_images_of_our_prop['t_min']
place_list = [1] * len(direct_image_tmin)
grism_tmin = visit_test_one['t_min']
place2 = [1] * len(grism_tmin)

# %%
p = figure(plot_width=1000, plot_height=600)

p.xaxis.axis_label="Exposure Start"

p.scatter(direct_image_tmin, place_list, size=5, line_color="navy", fill_color="teal", fill_alpha=0.5)
p.scatter(grism_tmin,place2, size=5, line_color="navy", fill_color="orange", fill_alpha=0.7)

show(p)

# %%
obsTableDecRA_pandas = obsTableDecRA.to_pandas()

# %%
s_regions_DecRA = obsTableDecRA_pandas['s_region']
print s_regions_DecRA
# Out:
# 0      POLYGON -170.96938183999998 62.20174028 -171.0...
# 1      POLYGON -170.92170848 62.22415487 -170.9936149...
# 2      POLYGON -170.87392052 62.24640496 -170.9458802...
# 3      POLYGON -170.82683977 62.27000459 -170.9011183...
# 4      POLYGON -170.91503954 62.17657156 -170.9868328...
# 5      POLYGON -170.86729349 62.198794 -170.93913998 ...
# 6      POLYGON -170.82080280000002 62.22350131 -170.8...
# 7      POLYGON -170.77180089 62.24326607 -170.8437531...
# 8      POLYGON -170.86062438 62.15118278 -170.9323576...
# 9      POLYGON -170.81283663 62.17340499 -170.8846225...
# 10     POLYGON -170.76513210999997 62.19565498 -170.8...
# 11     POLYGON -170.71734430000004 62.21787733 -170.7...
# 12     POLYGON -170.80844501 62.113211 -170.84993097 ...
# 13     POLYGON -170.75842137 62.14804389 -170.8301471...
# 14     POLYGON -170.71071697000002 62.1702661 -170.78...
# 15     POLYGON -170.66241273000003 62.19083358 -170.7...
# 16     POLYGON -170.77846933 62.29087706 -170.8505352...
# 17     POLYGON -170.72571441000002 62.3044966 -170.77...
# 18     POLYGON -170.67808479 62.32613115 -170.7259783...
# 19     POLYGON -170.63005498999996 62.34929169 -170.6...
# 20     POLYGON -170.72405449999997 62.26548818 -170.7...
# 21     POLYGON -170.67209417000004 62.277173 -170.716...
# 22     POLYGON -170.62453070000004 62.29896585 -170.6...
# 23     POLYGON -170.57675799000003 62.32123012 -170.6...
# 24     POLYGON -170.66464344999997 62.23122214 -170.7...
# 25     POLYGON -170.62189324999997 62.26234939 -170.6...
# 26     POLYGON -170.61442141999999 62.20955145 -170.6...
# 27     POLYGON -170.56743672 62.23696065 -170.6393741...
# 28     POLYGON -170.96919418 62.20180528 -171.0410474...
# 29     POLYGON -170.92144775999998 62.22402749 -170.9...
#                              ...
# 114    POLYGON -170.55617547999998 62.30384457 -170.5...
# 115    POLYGON -170.79515663 62.34078787 -170.8681638...
# 116    POLYGON -170.79515663 62.34078787 -170.8681638...
# 117    POLYGON -170.82053881000002 62.21465388 -170.8...
# 118    POLYGON -170.82053865 62.2146542 -170.86825589...
# 119    POLYGON -170.7334019 62.23337913 -170.76599806...
# 120    POLYGON -170.7900848 62.31536977 -170.83325982...
# 121    POLYGON -170.73340186999997 62.23337916 -170.7...
# 122    POLYGON -170.82660698 62.22788032 -170.9045954...
# 123    POLYGON -170.73397381 62.24764865 -170.8059418...
# 124    POLYGON -170.79196819000003 62.32616632 -170.8...
# 125    POLYGON -170.79196829 62.32616655 -170.8633911...
# 126    POLYGON -170.83791281000003 62.1998301 -170.83...
# 127    POLYGON -170.83791281000003 62.1998301 -170.83...
# 128    POLYGON -170.74509089000003 62.22478132 -170.7...
# 129    POLYGON -170.74509089000003 62.22478132 -170.7...
# 130    POLYGON -170.6553781 62.24321287 -170.66681030...
# 131    POLYGON -170.6553781 62.24321287 -170.66681030...
# 132    POLYGON -170.64742386 62.34455427 -170.6640590...
# 133    POLYGON -170.64742386 62.34455427 -170.6640590...
# 134    POLYGON -170.69468923 62.3018022 -170.72950286...
# 135    POLYGON -170.69468923 62.3018022 -170.72950286...
# 136    POLYGON -170.63677624000002 62.26100577 -170.6...
# 137    POLYGON -170.63127148 62.36286874 -170.6951452...
# 138    POLYGON -170.68719737000004 62.31377911 -170.7...
# 139    POLYGON -170.63418823999996 62.37282424 -170.7...
# 140    POLYGON -170.63418823999996 62.37282424 -170.7...
# 141    POLYGON -170.69090809 62.32568441 -170.7690270...
# 142    POLYGON -170.69090809 62.32568441 -170.7690270...
# 143    POLYGON -170.73340207 62.23337896 -170.7659976...
# Name: s_region, dtype: object

# %%
def polysplit(region='polygon(150.099223,2.391097,150.086084,2.422515,150.050573,2.407277,150.064586,2.376241)', get_shapely=False):
    
    spl = region[region.find('(')+1:region.find(')')].split(',')
    px = spl[0::2]
    py = spl[1::2]
    px.append(px[0])
    py.append(py[0])
    px, py = np.cast[float](px), np.cast[float](py)
    
    if get_shapely:
        from shapely.geometry import Polygon
        list = []
        for i in range(len(px)):
            list.append((px[i], py[i]))
        
        poly = Polygon(tuple(list))
        return poly
    else:
        return px, py

# %%
n=1
reg_type =  s_regions_DecRA[n].split()[0].lower()
reg_split =  s_regions_DecRA[n].split()
if reg_split[1].startswith('G'):
    coords = '('+','.join(reg_split[2:])+')'
else:
    coords = '('+','.join(reg_split[2:])+')'

test_reg = reg_type+coords 
poly_test1 = polysplit(test_reg, get_shapely=True)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-21-8bd81495dc43> in <module>()
#       8
#       9 test_reg = reg_type+coords
# ---> 10 poly_test1 = polysplit(test_reg, get_shapely=True)
#
# <ipython-input-20-d838f70a9ff8> in polysplit(region, get_shapely)
#      12         list = []
#      13         for i in range(len(px)):
# ---> 14             list.append((px[i], py[i]))
#      15
#      16         poly = Polygon(tuple(list))
#
# IndexError: index 6 is out of bounds for axis 0 with size 6

# %%
poly_test1

# %%
n=2
reg_type =  s_regions_DecRA[n].split()[0].lower()
reg_split =  s_regions_DecRA[n].split()
if reg_split[1].startswith('G'):
    coords = '('+','.join(reg_split[2:])+')'
else:
    coords = '('+','.join(reg_split[2:])+')'

test_reg2 = reg_type+coords 
poly_test2 = polysplit(test_reg2, get_shapely=True)

# %%
print(poly_test2)

# %%
print(poly_test1.intersection(poly_test2))
